# %% [markdown]
# Gabriel Lara 00215784

# %% [markdown]
# ## Verdadero o falso con argumentos

# %% [markdown]
# ### 1.  Una función recursiva resuelve un problema resolviendo una parte mas pequeña del mismo problema

# %% [markdown]
# Verdadero, cuando hablamos de recursividad, buscamos dividir el problema general en sub problemas que sea más fáciles de resolver, para que de esta manera resolver estos sub problemas mediante recursión o llamadas a si mismo de la función hasta llegar a un problema cuya solución sea algo trivial y pueda ser resuelto de manera sencilla.

# %% [markdown]
# ### 2.  Los modelos computacionales nos ayudan a analizar la complejidad de los algoritmos, ya que nos proveen de las especificaciones de la computadora en la cual estos se ejecutarían idealmente

# %% [markdown]
# Verdadero, los modelos computacionales permiten conocer las operaciones que se pueden realizar en un algoritmo, recursos como el uso de tiempo que conlleva realizar el algoritmo, el uso de la memoria, y el costo que conlleva asumiendo que hay un unico procesador.

# %% [markdown]
# ### 3.  La búsqueda en un árbol binario de búsqueda es siempre mas rápida que la búsqueda lineal en un arreglo

# %% [markdown]
# Falso, es cierto que un árbol binario de busqueda si estuviera balanceado sería más rapido que la busqueda lineal dentro de un arreglo, ya que al estar balanceado se conoce que los elementos de la izquierda seran menores que el valor de la raíz, y que los elementos de la derecha serán mayores que el valor de la raíz, pero no siempre se tiene un árbol binario de busqueda que esté balanceado, y que cumpla la condición mencionada anteriormente, por lo que la busqueda en ese caso sería de una complejidad mayor que dentro de un arreglo que deba recorrer todos los elementos de forma lineal para buscar el valor deseado.

# %% [markdown]
# ### 4. Un algoritmo de complejidad O(nlog(n)) es mas rápido que un algoritmo de complejidad O(n)

# %% [markdown]
# Falso, en nivel de complejidad O(n) es un algoritmo más rapido que un algoritmo O(nlog(n)) ya que este tendra un crecimiento mayor al ejecutarse y al estar multiplicandose por un valor n su crecimiento será aún mayor en comparación con un algoritmo de complejidad O(n) que sea lineal.

# %% [markdown]
# ### 5.  Un algoritmo de complejidad Ω(nlog(n)) es mas rápido que un algoritmo de complejidad Ω(n)

# %% [markdown]
# Falso, cuando hablamos de complejidad Omega, es decir el mejor caso dentro de un algoritmo,considerando un algoritmo con complejidad Ω(nlog(n)) tiende a crecer más y ser mas costoso que un algoritmo de complejidad Ω(n) ya que este algoritmo de complejidad incluso puede llegar a ser de valor 1 por lo que Ω(n) es un algoritmo de complejidad más rápido que un algoritmo de complejidad Ω(nlog(n))

# %% [markdown]
# ## Problemas de programación
# #### Todo el código debe ser en Python. Si se requiere escribir funciones que hagan búsqueda o ordenamiento (search, sort), programe las funciones usando los conceptos aprendidos en clase. No use las funciones que Python provee para hacer esto.

# %% [markdown]
# ### 6. Dada una lista enlazada que represente un número. Por ejemplo, 123 es representado por la lista 1->2->3 si la lista es simple o con doble enlace si es doble. Escriba un programa que haga lo siguiente:
#
# 1. Reciba dos números A y B como input
#
# 2. Transforme estos números a listas enlazadas como la definida arriba
#
# 3. Implemente la resta de los números descritos por esas listas enlazadas. El resultado (A-B) debe ser almacenado en una lista enlazada.
#
# 4. Imprima el resultado concatenando el valor de los nodos de la lista enlazada resultante
#
# Nota: asuma que el número A es mayor que B

# %%
##Clase Nodo
class Node:   
    def __init__(self, data=None, siguiente=None):
        self.data=data
        self.siguiente=siguiente

    def set_next(self,siguiente):
        self.siguiente=siguiente

##Clase singlyList
class singlyList:
    def __init__(self,head=None):
        self.head=None
    
    def transverar_Lista(self):
        generar_nodo=self.head
        print("El resultado de la resta es:")
        while generar_nodo:
            print(generar_nodo.data,end=" ")
            generar_nodo=generar_nodo.siguiente
          
    def insertar_alInicio(self,nuevo_head):
        antigua_head=self.head
        self.head=nuevo_head
        nuevo_head.set_next(antigua_head)  
    
    def size(self):
        temp=self.head
        contador=0
        while(temp):
            contador+=1
            temp=temp.siguiente
        return contador      
                        
    def restar_listas (A,B):
        Lista1=singlyList()
        Lista2=singlyList()
        Resultado=singlyList()
        print("Lista A :", end=" ")
        for i in A:
            node=Node(i)
            Lista1.insertar_alInicio(node)
            print(node.data, end=" ")

        print(" ")
        print("Lista B :", end=" ")          
        for j in B:
            node=Node(j)
            Lista2.insertar_alInicio(node)
            print(node.data, end=" ")
        print(" ")  
        inicio1=Lista1.head
        inicio2=Lista2.head
        restante=0
        varTempPrestado=0
        for k in range(Lista1.size()):
            var1=int(inicio1.data)
            var2=int(inicio2.data)
            #Verificacion de los valores para la resta individual Ej. 0-5 evitar Res=-5
            if var1 < var2 :
                var1+=10
                varTempPrestado=int(Lista2.head.siguiente.data) + 1
                Lista2.head.siguiente.data=varTempPrestado
            resta=var1-var2
  
            inicio1 = inicio1.siguiente
            inicio2 = inicio2.siguiente

            node=Node(resta)
            Resultado.insertar_alInicio(node)
            
            if k == Lista1.size():
                valTemp=Node(restante)
                Resultado.insertar_alInicio(valTemp)
            Lista2.head=Lista2.head.siguiente      
        return Resultado        
    
if __name__ == '__main__':     
       
    A=(input("Ingrese un numero A: "))
    B=(input("Ingrese un segundo numero B: "))
    Res=singlyList.restar_listas(A,B)
    Res.transverar_Lista()
# Out:
# Lista A : 2 5 0
# Lista B : 2 2 5
# El resultado de la resta es:
# 0 2 5

# %% [markdown]
# ### 7.  Cuando introducimos el concepto de pilas (stacks), usamos como ejemplos una pila de platos. Siguiendo con el ejemplo, una pila de platos con muchos platos se puede caer. Para evitar esto, se puede empezar una nueva pila.
#
# Implemente una clase de Python que defina un arreglo de stacks. La idea de tener este arreglo es que cuando un stack alcance su capacidad máxima, un nuevo stack empieza en el mismo arreglo. Las operación pop() debe retornar el mismo valor que lo haría si estuviéramos usando un stack simple.
#
# Nota: Debe definir los elementos de la clase: el arreglo de stacks, la capacidad del arreglo (# de stacks en el arreglo), la capacidad de cada stack (# de elementos que puede tener el stack).
#
# Hint: Cuando ingrese elementos (push), los elementos van al stack que este activo (el stack que recibe y retira elementos). Debe manejar las condiciones para cambiar el stack activo (cuando un push() deja al stack sin elementos, o cuando un pop() llena el stack).

# %%
##Clase nodo
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
##Clase stack
class Stack:
    def __init__(self,capacidad_maxima):
        self.capacidad_maxima=capacidad_maxima
        self.size=0
        self.top=None
        self.siguiente_nodo=None            

    def push(self,data):
        if not self.top:
            self.top=Node(data)
            self.size=1
        if self.size <= capacidad_maxima:
            nuevo_nodo=Node(data)
            nuevo_nodo.next=self.top
            self.top=nuevo_nodo
            self.size +=1    

    def pop(self):
        if not self.top:
            print("El stack ya esta vacio")
        nodo_eliminar=self.top
        self.top=self.top.next
        self.size-=1
        return nodo_eliminar

    def full(self):
        return self.size==self.capacidad_maxima

    def emply(self):
        return self.size==0

#Clase para generar Stacks cuando alcance la capacidad              
class GenerarStack:
    def __init__(self,capacidad_maxima):
        self.capacidad_maxima=capacidad_maxima
        self.item=None
        
    def push(self,data):
        if not self.item:
            nuevo_stack=Stack(self.capacidad_maxima)
            nuevo_stack.push(data)
            self.item=nuevo_stack

        if self.item.full():
            nuevo_stack=Stack(self.capacidad_maxima)
            nuevo_stack.push(data)
            nuevo_stack.siguiente_nodo=self.item

        if self.item.size<=self.item.capacidad_maxima:
            self.item.push(data)
                      
    def pop(self):
        elimiar_nodo=self.item.pop()
        if self.item.emply():
            self.item=self.item.siguiente_nodo
        return elimiar_nodo


if __name__ == "__main__":
    capacidad_maxima=2
    _Stacks=GenerarStack(capacidad_maxima)
    _Stacks.push(5)
    _Stacks.push(3)
    print("Stack con tamaño 2:",_Stacks.item)
    _Stacks.push(11)
    print("Stack superando capacidad",_Stacks.item)
    _Stacks.pop()
    print("Stack despues de metodo pop: ",_Stacks.item)
# Out:
# Stack con tamaño 2: <__main__.Stack object at 0x000001997A056C70>
# Stack superando capacidad <__main__.Stack object at 0x000001997A056C70>
# Stack despues de metodo pop:  <__main__.Stack object at 0x000001997A056C70>

# %% [markdown]
# ### 8. Dada una cola con prioridad (PriorityQueue) que contiene elementos (k,v) donde k define la prioridad y v define el valor. Recuerde que los valores con menor k tienen mayor prioridad, es decir si tenemos dos elementos (k1, v1) y (k2, v2), v2 tiene preferencia para salir de la cola antes que v1 si k2< k1. Definimos algunas de las operaciones como siguen:
#
# ```
# import ctypes
#
# class PriorityQueue(object):
#
# """
#
# Implementation of the queue data structure
#
# """
#
# def __init__(self, n):
#
# self.item_count = 0
#
# self.n = n
#
# self.queue = self._create_queue(self.n)
#
# def _create_queue(self, n):
#
# """
#
# Creates a new stack of capacity n
#
# """
#
# return (n * ctypes.py_object)()
#
# def dequeue(self):
#
# """
#
# Remove an element from the queue
#
# """
#
# c = self.queue[0]
#
# for i in range(1,self.item_count):
#
# self.queue[i-1] = self.queue[i]
#
# self.queue[self.item_count - 1] = ctypes.py_object
#
# self.item_count -= 1
#
# return c
# ```
#
# ### Implemente los métodos enqueue y decreaseKey, tal que ambos métodos tengan complejidad O(log(n)), sin utilizar funciones nativas de Python. Por ejemplo, si necesita hacer una búsqueda, no use la función de Python que implementa esto, programe la función usando for o while loops.

# %%
import ctypes

def binary_search(arreglo,var,inicio,final):
        if final-inicio<=1:
            if var[0]> arreglo.queue[inicio][0]:
                return inicio-1
            else:
                return inicio     
        medio=(inicio+final)//2
        if arreglo.queue[medio][0]>var[0]:
            return binary_search(arreglo,var,medio,final)
        elif arreglo.queue[medio] > var:
            return binary_search(arreglo,var,inicio,medio)
        else:
            return medio
        
def insertion_sort(arreglo):
        for i in range(1,arreglo.item_count):
            var=arreglo.queue[i]
            x=binary_search(arreglo,var,0,i)+1
            for k in range (i,x,-1):
                arreglo.queue[k]=arreglo.queue[k-1]
            arreglo.queue[x]=var
        return arreglo          
        
class PriorityQueue(object):
    def __init__(self, n):
        self.item_count = 0
        self.n = n
        self.queue = []
    
    #Funcion para imprimir Priority Queue llamando a la funcion print()    
    def __str__(self):
        return ' '.join([str(i) for i in self.queue])    
    
    def _create_queue(self, n): 
        return (n * ctypes.py_object)()
    
    def enqueue (self,valor,key):
        if (self.item_count == self.n):
            print("La cola está llena")
        self.queue.append((key,valor))
        self.item_count+=1
        insertion_sort(self)
                
    def decreaseKey(self,v,k):
            if self.queue[v][0]< k:
                print("El valor de k debe ser menor")
            self.queue[v]=(self.queue[v][0]-k,self.queue[v][1])
            insertion_sort(self)       

    def dequeue(self):    
        c = self.queue[0]
        for i in range(1,self.item_count):
            self.queue[i-1] = self.queue[i]
            self.queue[self.item_count - 1] = ctypes.py_object
            self.item_count -= 1
        return c
           
if __name__ == '__main__':  
   Resultado=PriorityQueue(5)
   Resultado.enqueue(1,5)
   Resultado.enqueue(1,4)
   Resultado.enqueue(2,3)
   Resultado.enqueue(3,2)
   Resultado.enqueue(4,1)
   print("PriorityQueue con los valores ingresados: ", Resultado) 
   Resultado.decreaseKey(3,1)
   print("PriorityQueue tras actualizar el key: ", Resultado)
# Out:
# PriorityQueue con los valores ingresados:  (5, 1) (4, 1) (3, 2) (2, 3) (1, 4)
# PriorityQueue tras actualizar el key:  (5, 1) (4, 1) (3, 2) (1, 3) (1, 4)

# %% [markdown]
# ### 9. Tenemos un árbol binario (binary tree), definimos a un nodo X como rojo, si todos los nodos en el recorrido de la raiz al nodo X tienen un valor que es menor o igual a X. Por ejemplo, en el ejemplo de abajo:
#
# ![](./binary_tree.png)
#
# El recorrido hacia el nodo 3 de la izquierda es 3 → 1 → 3, como todos los valores en este recorrido son menores o iguales a 3 (3=3 y 1<3), el nodo es rojo. Similarmente, en el sub-árbol de la derecha, los nodos 4 y 5 también son rojos. Escriba una función en Python que cuente el numero total de nodos rojos. El input de esta función es la raíz del árbol binario.

# %%
#Clase Nodo
class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.sub_Nodos = []
        
def EncontrarNodos(root: Nodo, var1: int):
    if root is None:
        return 0
    var_temp_Valores = 0
    if root.valor <= var1:
        var_temp_Valores += 1
    longitud_Hojas = len(root.sub_Nodos)
    for i in range(longitud_Hojas):
        child = root.sub_Nodos[i]
        var_temp_Valores += EncontrarNodos(child, var1)
    return var_temp_Valores

if __name__ == "__main__":
    Raiz = 3
    root = Nodo(3)
    #Crear formato del arbol del ejercicio
    (root.sub_Nodos).append(Nodo(1))
    (root.sub_Nodos).append(Nodo(4))
    (root.sub_Nodos[0].sub_Nodos).append(Nodo(3))
    (root.sub_Nodos[1].sub_Nodos).append(Nodo(1))
    (root.sub_Nodos[1].sub_Nodos).append(Nodo(5))
 
    print("Nodos rojos encontrados para la raiz de % d:  % d Nodos" %
        (Raiz, EncontrarNodos(root, Raiz)))
# Out:
# Nodos rojos encontrados para la raiz de  3:   4 Nodos
